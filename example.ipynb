# %% [markdown]
# # Vietnamese Financial Report Data
#
# This notebook is provided as a demo for how to use the data.

# %%
import pandas as pd
import os

# %%
pd.set_option('max_columns', None)
pd.set_option('max_colwidth', None)
pd.set_option('max_rows', None)

# %% [markdown]
# # Load data

# %%
BALANCE_SHEET_PATH = os.path.join('data', 'Balance Sheet', 'csv')

bs4 = pd.read_csv(os.path.join(BALANCE_SHEET_PATH, 'Q4 2021.csv'), encoding='utf8', index_col='ID')
bs4.head()
# Out:
#                                                  AAA           AAM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.336716e+12  1.630425e+11
# I. Tiền và các khoản tương đương tiền   1.987171e+12  6.181230e+10
# 1. Tiền                                 1.156983e+12  1.281230e+10
# 2. Các khoản tương đương tiền           8.301873e+11  4.900000e+10
#
#                                                  AAT           ABS  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.426627e+11  1.282207e+12
# I. Tiền và các khoản tương đương tiền   9.020255e+10  3.143094e+09
# 1. Tiền                                 9.020255e+10  3.143094e+09
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  ABT  ACB           ACC  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.953361e+11  NaN  8.064129e+11
# I. Tiền và các khoản tương đương tiền   6.806607e+10  NaN  9.211478e+10
# 1. Tiền                                 4.956607e+10  NaN  2.011478e+10
# 2. Các khoản tương đương tiền           1.850000e+10  NaN  7.200000e+10
#
#                                                  ACL           ADG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.157970e+12  3.750601e+11
# I. Tiền và các khoản tương đương tiền   1.021528e+11  1.059024e+10
# 1. Tiền                                 1.021528e+11  1.059024e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  ADS           AGG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.592492e+12  1.108980e+13
# I. Tiền và các khoản tương đương tiền   1.269430e+11  3.976381e+11
# 1. Tiền                                 1.268580e+11  2.908781e+11
# 2. Các khoản tương đương tiền           8.500000e+07  1.067600e+11
#
#                                                  AGM  AGR           AMD  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.287219e+12  NaN  2.041498e+12
# I. Tiền và các khoản tương đương tiền   2.316773e+11  NaN  9.870276e+09
# 1. Tiền                                 1.866773e+11  NaN  9.870276e+09
# 2. Các khoản tương đương tiền           4.500000e+10  NaN  0.000000e+00
#
#                                                  ANV           APC  APG  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.916543e+12  2.198101e+11  NaN
# I. Tiền và các khoản tương đương tiền   4.270108e+10  1.897111e+10  NaN
# 1. Tiền                                 7.401082e+09  8.567670e+09  NaN
# 2. Các khoản tương đương tiền           3.530000e+10  1.040344e+10  NaN
#
#                                                  APH           ASG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.632994e+12  6.305734e+11
# I. Tiền và các khoản tương đương tiền   2.176385e+12  1.373356e+11
# 1. Tiền                                 1.265638e+12  7.988564e+10
# 2. Các khoản tương đương tiền           9.107472e+11  5.744995e+10
#
#                                                  ASM           ASP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.278793e+12  9.801912e+11
# I. Tiền và các khoản tương đương tiền   8.005535e+11  8.724364e+10
# 1. Tiền                                 4.647956e+11  8.724364e+10
# 2. Các khoản tương đương tiền           3.357579e+11  0.000000e+00
#
#                                                  BAF           BBC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.310728e+12  6.500620e+11
# I. Tiền và các khoản tương đương tiền   2.908852e+11  1.771725e+11
# 1. Tiền                                 2.656352e+11  4.210708e+10
# 2. Các khoản tương đương tiền           2.525000e+10  1.350655e+11
#
#                                                  BCE           BCG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.870639e+11  1.638784e+13
# I. Tiền và các khoản tương đương tiền   7.185174e+10  1.053017e+12
# 1. Tiền                                 2.485174e+10  6.622868e+11
# 2. Các khoản tương đương tiền           4.700000e+10  3.907300e+11
#
#                                                  BFC           BHN  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.048410e+12  4.342028e+12
# I. Tiền và các khoản tương đương tiền   2.439416e+11  7.624154e+11
# 1. Tiền                                 2.439416e+11  6.047094e+11
# 2. Các khoản tương đương tiền           0.000000e+00  1.577060e+11
#
#                                                  BIC  BID           BKG  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.155038e+12  NaN  3.272488e+11
# I. Tiền và các khoản tương đương tiền            NaN  NaN  3.943137e+10
# 1. Tiền                                          NaN  NaN  3.943137e+10
# 2. Các khoản tương đương tiền                    NaN  NaN  0.000000e+00
#
#                                                  BMC           BMI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.887506e+11  6.408281e+12
# I. Tiền và các khoản tương đương tiền   7.954497e+10           NaN
# 1. Tiền                                 7.954497e+10           NaN
# 2. Các khoản tương đương tiền           0.000000e+00           NaN
#
#                                                  BMP           BRC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.056868e+12  2.007888e+11
# I. Tiền và các khoản tương đương tiền   1.729387e+11  1.445607e+10
# 1. Tiền                                 4.043868e+10  1.445607e+10
# 2. Các khoản tương đương tiền           1.325000e+11  0.000000e+00
#
#                                                  BTP           BTT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.804173e+11  8.812370e+10
# I. Tiền và các khoản tương đương tiền   1.053355e+11  1.533699e+10
# 1. Tiền                                 2.335519e+09  4.114252e+09
# 2. Các khoản tương đương tiền           1.030000e+11  1.122274e+10
#
#                                                  BWE           C32  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.718621e+12  5.413683e+11
# I. Tiền và các khoản tương đương tiền   4.760047e+11  1.137613e+11
# 1. Tiền                                 1.591302e+11  4.799840e+10
# 2. Các khoản tương đương tiền           3.168745e+11  6.576289e+10
#
#                                                  C47           CAV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.049848e+12  5.156565e+12
# I. Tiền và các khoản tương đương tiền   9.877412e+10  6.560001e+10
# 1. Tiền                                 9.877412e+10  6.560001e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  CCI           CCL  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.642601e+11  1.120867e+12
# I. Tiền và các khoản tương đương tiền   2.067600e+10  1.364905e+10
# 1. Tiền                                 1.599343e+10  1.364905e+10
# 2. Các khoản tương đương tiền           4.682568e+09  0.000000e+00
#
#                                                  CDC           CEE  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.104862e+12  2.068789e+12
# I. Tiền và các khoản tương đương tiền   3.513263e+10  4.164008e+10
# 1. Tiền                                 2.175059e+10  4.164008e+10
# 2. Các khoản tương đương tiền           1.338203e+10  0.000000e+00
#
#                                                  CHP           CII  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.953595e+11  1.057191e+13
# I. Tiền và các khoản tương đương tiền   9.103868e+10  6.898105e+11
# 1. Tiền                                 5.038683e+09  5.160226e+11
# 2. Các khoản tương đương tiền           8.600000e+10  1.737879e+11
#
#                                                  CKG           CLC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.015602e+12  1.006965e+12
# I. Tiền và các khoản tương đương tiền   7.184533e+10  6.197152e+10
# 1. Tiền                                 6.984533e+10  6.197152e+10
# 2. Các khoản tương đương tiền           2.000000e+09  0.000000e+00
#
#                                                  CLL           CLW  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.299461e+11  2.119364e+11
# I. Tiền và các khoản tương đương tiền   2.215341e+11  7.923980e+10
# 1. Tiền                                 1.320040e+10  2.023980e+10
# 2. Các khoản tương đương tiền           2.083337e+11  5.900000e+10
#
#                                                  CMG           CMV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.739980e+12  3.598921e+11
# I. Tiền và các khoản tương đương tiền   3.901141e+11  3.167331e+10
# 1. Tiền                                 2.539641e+11  2.817331e+10
# 2. Các khoản tương đương tiền           1.361500e+11  3.500000e+09
#
#                                                  CMX           CNG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.533112e+12  8.277736e+11
# I. Tiền và các khoản tương đương tiền   2.683760e+10  2.824770e+11
# 1. Tiền                                 2.683760e+10  2.747705e+10
# 2. Các khoản tương đương tiền           0.000000e+00  2.550000e+11
#
#                                                  COM           CRC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.268317e+11  2.557582e+11
# I. Tiền và các khoản tương đương tiền   8.518798e+10  1.672708e+10
# 1. Tiền                                 2.318798e+10  1.672708e+10
# 2. Các khoản tương đương tiền           6.200000e+10  0.000000e+00
#
#                                                  CRE           CSM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.117661e+12  2.804227e+12
# I. Tiền và các khoản tương đương tiền   1.250026e+11  7.894146e+10
# 1. Tiền                                 1.219305e+11  7.894146e+10
# 2. Các khoản tương đương tiền           3.072018e+09  0.000000e+00
#
#                                                  CSV           CTD  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.356808e+11  1.351939e+13
# I. Tiền và các khoản tương đương tiền   1.822159e+11  8.847105e+11
# 1. Tiền                                 8.221588e+10  4.107105e+11
# 2. Các khoản tương đương tiền           1.000000e+11  4.740000e+11
#
#                                                  CTF  CTG           CTI  CTS  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.196356e+12  NaN  5.139727e+11  NaN
# I. Tiền và các khoản tương đương tiền   5.552759e+10  NaN  2.178663e+11  NaN
# 1. Tiền                                 4.852759e+10  NaN  1.847320e+11  NaN
# 2. Các khoản tương đương tiền           7.000000e+09  NaN  3.313433e+10  NaN
#
#                                                  CVT           D2D  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.666590e+12  8.614523e+11
# I. Tiền và các khoản tương đương tiền   8.572220e+10  1.764251e+10
# 1. Tiền                                 8.572220e+10  1.764251e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  DAH           DAT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.035259e+11  1.151880e+12
# I. Tiền và các khoản tương đương tiền   7.058619e+09  2.794869e+11
# 1. Tiền                                 7.058619e+09  1.159432e+11
# 2. Các khoản tương đương tiền           0.000000e+00  1.635437e+11
#
#                                                  DBC           DBD  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.598671e+12  9.723105e+11
# I. Tiền và các khoản tương đương tiền   2.000571e+11  6.845378e+10
# 1. Tiền                                 1.972124e+11  3.145378e+10
# 2. Các khoản tương đương tiền           2.844700e+09  3.700000e+10
#
#                                                  DBT           DC4  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.269946e+11  8.883642e+11
# I. Tiền và các khoản tương đương tiền   1.896284e+10  1.952238e+11
# 1. Tiền                                 1.896284e+10  1.872238e+11
# 2. Các khoản tương đương tiền           0.000000e+00  8.000000e+09
#
#                                                  DCL           DCM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.261155e+12  7.282185e+12
# I. Tiền và các khoản tương đương tiền   4.125526e+10  4.276527e+11
# 1. Tiền                                 1.490932e+10  4.276527e+11
# 2. Các khoản tương đương tiền           2.634595e+10  0.000000e+00
#
#                                                  DGC           DGW  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.815714e+12  6.258548e+12
# I. Tiền và các khoản tương đương tiền   1.239578e+11  1.494332e+12
# 1. Tiền                                 1.149578e+11  2.509937e+11
# 2. Các khoản tương đương tiền           9.000000e+09  1.243338e+12
#
#                                                  DHA           DHC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.938998e+11  1.170473e+12
# I. Tiền và các khoản tương đương tiền   1.335716e+11  9.816947e+10
# 1. Tiền                                 5.507158e+10  5.816947e+10
# 2. Các khoản tương đương tiền           7.850000e+10  4.000000e+10
#
#                                                  DHG           DHM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.727293e+12  3.304079e+11
# I. Tiền và các khoản tương đương tiền   4.337352e+10  3.283273e+10
# 1. Tiền                                 4.337352e+10  2.102073e+10
# 2. Các khoản tương đương tiền           0.000000e+00  1.181200e+10
#
#                                                  DIG           DLG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.121778e+13  2.450738e+12
# I. Tiền và các khoản tương đương tiền   1.000229e+12  8.226513e+10
# 1. Tiền                                 3.807562e+11  8.226513e+10
# 2. Các khoản tương đương tiền           6.194725e+11  0.000000e+00
#
#                                                  DMC           DPG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.421637e+12  2.769619e+12
# I. Tiền và các khoản tương đương tiền   8.537680e+10  1.046137e+12
# 1. Tiền                                 8.537680e+10  3.294775e+11
# 2. Các khoản tương đương tiền           0.000000e+00  7.166599e+11
#
#                                                  DPM           DPR  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.519481e+12  1.625736e+12
# I. Tiền và các khoản tương đương tiền   2.524115e+12  5.926542e+11
# 1. Tiền                                 5.671494e+11  1.352583e+11
# 2. Các khoản tương đương tiền           1.956966e+12  4.573958e+11
#
#                                                  DQC           DRC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.384276e+11  2.117309e+12
# I. Tiền và các khoản tương đương tiền   5.650782e+10  8.962117e+10
# 1. Tiền                                 2.490782e+10  3.262117e+10
# 2. Các khoản tương đương tiền           3.160000e+10  5.700000e+10
#
#                                                  DRH           DRL  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.760868e+12  9.473654e+10
# I. Tiền và các khoản tương đương tiền   4.921903e+10  1.117059e+10
# 1. Tiền                                 4.921903e+10  1.170586e+09
# 2. Các khoản tương đương tiền           0.000000e+00  1.000000e+10
#
#                                                  DSN           DTA  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.848448e+11  2.391628e+11
# I. Tiền và các khoản tương đương tiền   7.245365e+10  4.299054e+10
# 1. Tiền                                 4.087857e+09  1.676897e+10
# 2. Các khoản tương đương tiền           6.836579e+10  2.622157e+10
#
#                                                  DTL           DVP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.182609e+12  1.170117e+12
# I. Tiền và các khoản tương đương tiền   5.511017e+09  3.280939e+10
# 1. Tiền                                 5.511017e+09  3.280939e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  DXG           DXS  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.523004e+13  1.450514e+13
# I. Tiền và các khoản tương đương tiền   2.737677e+12  1.632448e+12
# 1. Tiền                                 9.197890e+11  4.371104e+11
# 2. Các khoản tương đương tiền           1.817888e+12  1.195338e+12
#
#                                                  DXV  EIB           ELC  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.186052e+11  NaN  8.783453e+11
# I. Tiền và các khoản tương đương tiền   9.900447e+09  NaN  1.546546e+11
# 1. Tiền                                 9.900447e+09  NaN  1.189322e+11
# 2. Các khoản tương đương tiền           0.000000e+00  NaN  3.572246e+10
#
#                                                  EMC           EVE  EVF  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.643602e+11  9.656110e+11  NaN
# I. Tiền và các khoản tương đương tiền   8.996502e+09  5.216207e+10  NaN
# 1. Tiền                                 8.202324e+09  2.585917e+10  NaN
# 2. Các khoản tương đương tiền           7.941780e+08  2.630290e+10  NaN
#
#                                                  EVG           FCM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.381479e+12  6.510433e+11
# I. Tiền và các khoản tương đương tiền   6.867301e+10  6.355697e+10
# 1. Tiền                                 6.867301e+10  4.055697e+10
# 2. Các khoản tương đương tiền           0.000000e+00  2.300000e+10
#
#                                                  FCN           FDC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.142769e+12  5.217585e+11
# I. Tiền và các khoản tương đương tiền   3.157237e+11  4.670424e+10
# 1. Tiền                                 1.793610e+11  4.670424e+10
# 2. Các khoản tương đương tiền           1.363626e+11  0.000000e+00
#
#                                                  FIR           FIT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.544905e+11  3.695009e+12
# I. Tiền và các khoản tương đương tiền   1.688266e+10  2.974338e+11
# 1. Tiền                                 1.688266e+10  1.360878e+11
# 2. Các khoản tương đương tiền           0.000000e+00  1.613459e+11
#
#                                                  FLC           FMC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.763688e+13  2.140949e+12
# I. Tiền và các khoản tương đương tiền   1.761507e+11  7.695923e+11
# 1. Tiền                                 8.692392e+10  3.806553e+11
# 2. Các khoản tương đương tiền           8.922680e+10  3.889370e+11
#
#                                                  FPT           FRT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.511678e+13  1.017665e+13
# I. Tiền và các khoản tương đương tiền   5.417845e+12  1.105210e+12
# 1. Tiền                                 3.447377e+12  6.799388e+11
# 2. Các khoản tương đương tiền           1.970468e+12  4.252708e+11
#
#                                                  FTM  FTS           GAB  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.560318e+11  NaN  1.834677e+11
# I. Tiền và các khoản tương đương tiền   5.927266e+09  NaN  1.515315e+09
# 1. Tiền                                 5.927266e+09  NaN  1.515315e+09
# 2. Các khoản tương đương tiền           0.000000e+00  NaN  0.000000e+00
#
#                                                  GAS           GDT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.139528e+13  2.140429e+11
# I. Tiền và các khoản tương đương tiền   5.600331e+12  1.499528e+09
# 1. Tiền                                 1.395850e+12  1.499528e+09
# 2. Các khoản tương đương tiền           4.204481e+12  0.000000e+00
#
#                                                  GEG           GEX  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.316250e+12  2.986886e+13
# I. Tiền và các khoản tương đương tiền   2.558167e+11  4.781521e+12
# 1. Tiền                                 1.474417e+11  3.447688e+12
# 2. Các khoản tương đương tiền           1.083750e+11  1.333833e+12
#
#                                                  GIL           GMC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.151653e+12  6.151716e+11
# I. Tiền và các khoản tương đương tiền   6.272185e+11  3.343172e+11
# 1. Tiền                                 4.192185e+11  3.343172e+11
# 2. Các khoản tương đương tiền           2.080000e+11  0.000000e+00
#
#                                                  GMD           GSP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.690488e+12  5.498905e+11
# I. Tiền và các khoản tương đương tiền   6.372591e+11  1.395778e+11
# 1. Tiền                                 4.307591e+11  9.577833e+09
# 2. Các khoản tương đương tiền           2.065000e+11  1.300000e+11
#
#                                                  GTA           GTN  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.311461e+11  3.242054e+12
# I. Tiền và các khoản tương đương tiền   1.928284e+10  1.782112e+11
# 1. Tiền                                 1.928284e+10  6.321124e+10
# 2. Các khoản tương đương tiền           0.000000e+00  1.150000e+11
#
#                                                  GVR           HAG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.284345e+13  5.624733e+12
# I. Tiền và các khoản tương đương tiền   5.328589e+12  7.824359e+10
# 1. Tiền                                 2.335554e+12  7.824359e+10
# 2. Các khoản tương đương tiền           2.993035e+12  0.000000e+00
#
#                                                  HAH           HAI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.287238e+12  2.390189e+12
# I. Tiền và các khoản tương đương tiền   4.847324e+11  3.906043e+09
# 1. Tiền                                 2.074812e+11  3.906043e+09
# 2. Các khoản tương đương tiền           2.772512e+11  0.000000e+00
#
#                                                  HAP           HAR  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.551788e+11  9.065532e+10
# I. Tiền và các khoản tương đương tiền   1.527847e+10  3.181628e+10
# 1. Tiền                                 1.527847e+10  3.181628e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HAS           HAX  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.797587e+11  9.357781e+11
# I. Tiền và các khoản tương đương tiền   4.034029e+09  8.755323e+10
# 1. Tiền                                 2.467964e+09  8.755323e+10
# 2. Các khoản tương đương tiền           1.566065e+09  0.000000e+00
#
#                                                  HBC           HCD  HCM  HDB  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.512205e+13  4.367310e+11  NaN  NaN
# I. Tiền và các khoản tương đương tiền   7.329961e+11  1.718943e+10  NaN  NaN
# 1. Tiền                                 6.693439e+11  1.718943e+10  NaN  NaN
# 2. Các khoản tương đương tiền           6.365221e+10  0.000000e+00  NaN  NaN
#
#                                                  HDC           HDG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.671223e+12  4.175041e+12
# I. Tiền và các khoản tương đương tiền   6.169137e+10  2.156623e+11
# 1. Tiền                                 6.169137e+10  1.921623e+11
# 2. Các khoản tương đương tiền           0.000000e+00  2.350000e+10
#
#                                                  HHP           HHS  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.518200e+11  7.967351e+11
# I. Tiền và các khoản tương đương tiền   7.685824e+09  8.063098e+10
# 1. Tiền                                 7.685824e+09  8.063098e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HHV           HID  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.373642e+12  4.060658e+11
# I. Tiền và các khoản tương đương tiền   2.623835e+11  1.733686e+10
# 1. Tiền                                 2.047747e+11  2.411859e+09
# 2. Các khoản tương đương tiền           5.760877e+10  1.492500e+10
#
#                                                  HII           HMC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.709755e+12  1.136216e+12
# I. Tiền và các khoản tương đương tiền   1.012184e+11  2.079000e+10
# 1. Tiền                                 1.012184e+11  2.079000e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HOT           HPG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.510489e+10  9.415441e+13
# I. Tiền và các khoản tương đương tiền   1.109884e+10  2.247138e+13
# 1. Tiền                                 4.398836e+09  6.316300e+12
# 2. Các khoản tương đương tiền           6.700000e+09  1.615508e+13
#
#                                                  HPX           HQC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.782684e+12  3.504619e+12
# I. Tiền và các khoản tương đương tiền   6.347216e+11  2.985295e+10
# 1. Tiền                                 6.347216e+11  2.985295e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HRC           HSG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  8.266970e+10  1.511422e+13
# I. Tiền và các khoản tương đương tiền   2.504261e+10  1.018388e+12
# 1. Tiền                                 2.504261e+10  5.452480e+11
# 2. Các khoản tương đương tiền           0.000000e+00  4.731396e+11
#
#                                                  HSL           HT1  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.665816e+11  1.524040e+12
# I. Tiền và các khoản tương đương tiền   5.760723e+09  2.962191e+11
# 1. Tiền                                 5.760723e+09  2.406815e+11
# 2. Các khoản tương đương tiền           0.000000e+00  5.553752e+10
#
#                                                  HTI           HTL  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.172612e+10  2.728708e+11
# I. Tiền và các khoản tương đương tiền   1.995822e+10  5.526435e+10
# 1. Tiền                                 1.995822e+10  5.526435e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HTN           HTV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.003273e+12  3.497106e+11
# I. Tiền và các khoản tương đương tiền   4.281252e+11  1.343579e+10
# 1. Tiền                                 3.535407e+11  1.343579e+10
# 2. Các khoản tương đương tiền           7.458450e+10  0.000000e+00
#
#                                                  HU1           HU3  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.517640e+11  3.096494e+11
# I. Tiền và các khoản tương đương tiền   3.745752e+10  1.353596e+10
# 1. Tiền                                 3.745752e+10  1.353596e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  HUB           HVH  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.303839e+11  4.467159e+11
# I. Tiền và các khoản tương đương tiền   8.798057e+10  4.954422e+10
# 1. Tiền                                 1.566104e+10  2.052131e+10
# 2. Các khoản tương đương tiền           7.231953e+10  2.902290e+10
#
#                                                  HVX           IBC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.542189e+11  2.428651e+12
# I. Tiền và các khoản tương đương tiền   4.805266e+09  6.569743e+11
# 1. Tiền                                 4.805266e+09  5.369743e+11
# 2. Các khoản tương đương tiền           0.000000e+00  1.200000e+11
#
#                                                  ICT           IDI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.893430e+12  5.515358e+12
# I. Tiền và các khoản tương đương tiền   4.577152e+11  5.207310e+11
# 1. Tiền                                 1.558964e+11  3.271873e+11
# 2. Các khoản tương đương tiền           3.018188e+11  1.935437e+11
#
#                                                  IJC           ILB  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.773839e+12  3.170521e+11
# I. Tiền và các khoản tương đương tiền   1.467027e+11  1.013816e+11
# 1. Tiền                                 6.387784e+10  5.388164e+10
# 2. Các khoản tương đương tiền           8.282482e+10  4.750000e+10
#
#                                                  IMP           ITA  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.176340e+12  6.054222e+12
# I. Tiền và các khoản tương đương tiền   2.712729e+11  2.331591e+11
# 1. Tiền                                 4.627287e+10  2.316591e+11
# 2. Các khoản tương đương tiền           2.250000e+11  1.500000e+09
#
#                                                  ITC           KBC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.461100e+12  2.643545e+13
# I. Tiền và các khoản tương đương tiền   6.079719e+10  2.562237e+12
# 1. Tiền                                 4.054619e+10  7.279742e+11
# 2. Các khoản tương đương tiền           2.025100e+10  1.834263e+12
#
#                                                  KDC           KDH  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.073877e+12  1.339948e+13
# I. Tiền và các khoản tương đương tiền   1.281295e+12  1.365377e+12
# 1. Tiền                                 1.108748e+12  3.732255e+11
# 2. Các khoản tương đương tiền           1.725470e+11  9.921515e+11
#
#                                                  KHG           KHP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.216351e+12  7.866801e+11
# I. Tiền và các khoản tương đương tiền   5.638076e+11  1.172431e+11
# 1. Tiền                                 5.638076e+11  6.130091e+09
# 2. Các khoản tương đương tiền           0.000000e+00  1.111130e+11
#
#                                                  KMR           KOS  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.891284e+11  2.365572e+12
# I. Tiền và các khoản tương đương tiền   2.219288e+10  1.514614e+10
# 1. Tiền                                 2.219288e+10  1.514614e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  KPF           KSB  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.674682e+11  2.095410e+12
# I. Tiền và các khoản tương đương tiền   3.166638e+09  9.418972e+10
# 1. Tiền                                 1.166638e+09  8.418972e+10
# 2. Các khoản tương đương tiền           2.000000e+09  1.000000e+10
#
#                                                  L10           LAF  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.075457e+12  1.894030e+11
# I. Tiền và các khoản tương đương tiền   4.014127e+11  2.450552e+10
# 1. Tiền                                 4.014127e+11  5.005524e+09
# 2. Các khoản tương đương tiền           0.000000e+00  1.950000e+10
#
#                                                  LBM           LCG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.178816e+11  3.690906e+12
# I. Tiền và các khoản tương đương tiền   4.941700e+10  2.561361e+11
# 1. Tiền                                 1.938156e+10  2.445361e+11
# 2. Các khoản tương đương tiền           3.003544e+10  1.160000e+10
#
#                                                  LCM           LDG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.967672e+10  4.748958e+12
# I. Tiền và các khoản tương đương tiền   6.013531e+08  7.494989e+10
# 1. Tiền                                 6.013531e+08  7.494989e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  LEC           LGC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.364621e+11  1.187130e+12
# I. Tiền và các khoản tương đương tiền   1.211181e+10  1.830145e+11
# 1. Tiền                                 1.211181e+10  3.205655e+10
# 2. Các khoản tương đương tiền           0.000000e+00  1.509579e+11
#
#                                                  LGL           LHG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.070194e+12  2.014341e+12
# I. Tiền và các khoản tương đương tiền   1.921935e+10  9.185769e+10
# 1. Tiền                                 1.921935e+10  6.305033e+10
# 2. Các khoản tương đương tiền           0.000000e+00  2.880736e+10
#
#                                                  LIX           LM8  LPB  MBB  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.982407e+11  1.148191e+12  NaN  NaN
# I. Tiền và các khoản tương đương tiền   1.409524e+11  1.497863e+10  NaN  NaN
# 1. Tiền                                 2.095245e+10  1.497863e+10  NaN  NaN
# 2. Các khoản tương đương tiền           1.200000e+11  0.000000e+00  NaN  NaN
#
#                                                  MCG           MCP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.409164e+11  2.445574e+11
# I. Tiền và các khoản tương đương tiền   1.263810e+10  2.452578e+10
# 1. Tiền                                 1.263810e+10  2.452578e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  MDG           MHC  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.824343e+11  1.175013e+12
# I. Tiền và các khoản tương đương tiền   2.346263e+10  1.421804e+11
# 1. Tiền                                 2.346263e+10  1.421804e+11
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  MIG  MSB           MSH  \
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.661286e+12  NaN  2.489368e+12
# I. Tiền và các khoản tương đương tiền            NaN  NaN  3.786014e+11
# 1. Tiền                                          NaN  NaN  1.536863e+11
# 2. Các khoản tương đương tiền                    NaN  NaN  2.249151e+11
#
#                                                  MSN           MWG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.363018e+13  5.197615e+13
# I. Tiền và các khoản tương đương tiền   2.230482e+13  4.943933e+12
# 1. Tiền                                 6.885412e+12  2.606672e+12
# 2. Các khoản tương đương tiền           1.541941e+13  2.337261e+12
#
#                                                  NAF           NAV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.032908e+12  1.653500e+11
# I. Tiền và các khoản tương đương tiền   5.169831e+10  1.166598e+09
# 1. Tiền                                 6.267076e+09  1.166598e+09
# 2. Các khoản tương đương tiền           4.543124e+10  0.000000e+00
#
#                                                  NBB           NCT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.845736e+12  3.877625e+11
# I. Tiền và các khoản tương đương tiền   3.019034e+10  5.991893e+10
# 1. Tiền                                 3.019034e+10  9.698931e+09
# 2. Các khoản tương đương tiền           0.000000e+00  5.022000e+10
#
#                                                  NHA           NHH  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.007358e+11  8.435216e+11
# I. Tiền và các khoản tương đương tiền   7.204970e+08  8.893295e+10
# ...
# 2. Các khoản tương đương tiền           0.000000e+00  NaN  5.060025e+10
#
#                                                  TIS           BWS  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.717294e+12  3.000231e+11
# I. Tiền và các khoản tương đương tiền   2.564115e+11  6.062635e+10
# 1. Tiền                                 2.564115e+11  5.226351e+09
# 2. Các khoản tương đương tiền           0.000000e+00  5.540000e+10
#
#                                                  IRC           SVG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.365245e+11  1.621632e+11
# I. Tiền và các khoản tương đương tiền   1.141186e+10  1.524720e+10
# 1. Tiền                                 1.811865e+09  1.524720e+10
# 2. Các khoản tương đương tiền           9.600000e+09  0.000000e+00
#
#                                                  SJM           ISH  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.444929e+10  6.967267e+10
# I. Tiền và các khoản tương đương tiền   8.996845e+08  6.340236e+09
# 1. Tiền                                 8.996845e+08  1.340236e+09
# 2. Các khoản tương đương tiền           0.000000e+00  5.000000e+09
#
#                                                  NDW           MDF  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.019199e+11  4.197161e+11
# I. Tiền và các khoản tương đương tiền   4.569452e+10  3.763233e+10
# 1. Tiền                                 4.569452e+10  3.763233e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  ABR           CC4  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.389726e+11  4.543833e+11
# I. Tiền và các khoản tương đương tiền   4.927286e+10  3.283789e+10
# 1. Tiền                                 2.777286e+10  2.433789e+10
# 2. Các khoản tương đương tiền           2.150000e+10  8.500000e+09
#
#                                                  CTW           BPW  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.269188e+11  1.222665e+11
# I. Tiền và các khoản tương đương tiền   2.963260e+10  2.481863e+09
# 1. Tiền                                 1.191255e+10  2.481863e+09
# 2. Các khoản tương đương tiền           1.772005e+10  0.000000e+00
#
#                                                  CCA           CCT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.868710e+11  7.793562e+10
# I. Tiền và các khoản tương đương tiền   1.414928e+10  2.784012e+10
# 1. Tiền                                 1.414928e+10  1.154674e+10
# 2. Các khoản tương đương tiền           0.000000e+00  1.629338e+10
#
#                                                  FCS           CPI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.486175e+10  1.857492e+10
# I. Tiền và các khoản tương đương tiền   2.417368e+09  2.356176e+09
# 1. Tiền                                 2.417368e+09  2.356176e+09
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  CPA           CBI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.058540e+10  5.003704e+11
# I. Tiền và các khoản tương đương tiền   6.112788e+09  2.338755e+10
# 1. Tiền                                 6.112788e+09  2.338755e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  SP2           ACV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  7.719777e+10  3.727805e+13
# I. Tiền và các khoản tương đương tiền   4.283373e+10  5.728332e+11
# 1. Tiền                                 3.913373e+10  5.728332e+11
# 2. Các khoản tương đương tiền           3.700000e+09  0.000000e+00
#
#                                                  DBW           THP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.385229e+10  8.595863e+11
# I. Tiền và các khoản tương đương tiền   6.129851e+09  1.176275e+10
# 1. Tiền                                 6.129851e+09  1.176275e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  PIV           CMI  TIN  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.253209e+09  1.252732e+11  NaN
# I. Tiền và các khoản tương đương tiền   9.214994e+08  3.731956e+08  NaN
# 1. Tiền                                 9.214994e+08  3.731956e+08  NaN
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00  NaN
#
#                                                  ADP           PXA  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.707096e+11  1.206515e+11
# I. Tiền và các khoản tương đương tiền   1.056326e+10  6.041389e+08
# 1. Tiền                                 1.056326e+10  6.041389e+08
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  LDW           SCL  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.713049e+11  1.207515e+11
# I. Tiền và các khoản tương đương tiền   2.522496e+10  1.465799e+10
# 1. Tiền                                 2.522496e+10  1.465799e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  C21           UDJ  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.612836e+11  3.801767e+11
# I. Tiền và các khoản tương đương tiền   1.815727e+10  2.747498e+10
# 1. Tiền                                 1.665727e+10  2.474975e+09
# 2. Các khoản tương đương tiền           1.500000e+09  2.500000e+10
#
#                                                  VRG           PXM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.171130e+11  4.186500e+10
# I. Tiền và các khoản tương đương tiền   1.517234e+10  3.254701e+08
# 1. Tiền                                 1.017234e+10  3.254701e+08
# 2. Các khoản tương đương tiền           5.000000e+09  0.000000e+00
#
#                                                  PQN           TOP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.064552e+11  4.335212e+09
# I. Tiền và các khoản tương đương tiền   5.057991e+10  4.269280e+09
# 1. Tiền                                 4.210051e+10  4.269280e+09
# 2. Các khoản tương đương tiền           8.479404e+09  0.000000e+00
#
#                                                  TTS           HSV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.084444e+11  1.647582e+11
# I. Tiền và các khoản tương đương tiền   3.595816e+09  1.368944e+10
# 1. Tiền                                 3.595816e+09  1.368944e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  TDS           BHA  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  5.475110e+11  2.448944e+10
# I. Tiền và các khoản tương đương tiền   1.410251e+10  1.446361e+09
# 1. Tiền                                 1.410251e+10  1.446361e+09
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  BRR           BDG  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.599606e+11  7.050450e+11
# I. Tiền và các khoản tương đương tiền   6.673312e+10  3.448818e+10
# 1. Tiền                                 3.331180e+08  3.448818e+10
# 2. Các khoản tương đương tiền           6.640000e+10  0.000000e+00
#
#                                                  BDW           BDT  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.782353e+10  5.306812e+11
# I. Tiền và các khoản tương đương tiền   3.742704e+10  2.224677e+10
# 1. Tiền                                 9.927036e+09  2.224677e+10
# 2. Các khoản tương đương tiền           2.750000e+10  0.000000e+00
#
#                                                  SWC           BQB  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.524718e+11  1.371422e+10
# I. Tiền và các khoản tương đương tiền   1.892693e+11  1.512890e+09
# 1. Tiền                                 4.026934e+10  5.068640e+08
# 2. Các khoản tương đương tiền           1.490000e+11  1.006025e+09
#
#                                                  CDO           CDP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  9.751119e+10  1.802754e+12
# I. Tiền và các khoản tương đương tiền   9.926701e+08  8.733133e+10
# 1. Tiền                                 9.926701e+08  8.733133e+10
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00
#
#                                                  CQN           DRI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  4.214211e+11  2.035309e+11
# I. Tiền và các khoản tương đương tiền   2.951310e+10  8.491623e+10
# 1. Tiền                                 2.951310e+10  7.991623e+10
# 2. Các khoản tương đương tiền           0.000000e+00  5.000000e+09
#
#                                                  CQT           DDV  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  6.653949e+10  9.111021e+11
# I. Tiền và các khoản tương đương tiền   7.468868e+09  2.722798e+11
# 1. Tiền                                 7.468868e+09  1.727983e+10
# 2. Các khoản tương đương tiền           0.000000e+00  2.550000e+11
#
#                                                  HNR           AGP  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.034799e+11  4.947884e+11
# I. Tiền và các khoản tương đương tiền   8.165103e+09  2.417696e+10
# 1. Tiền                                 5.165103e+09  1.867696e+10
# 2. Các khoản tương đương tiền           3.000000e+09  5.500000e+09
#
#                                                  SQC           PVM  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.357499e+09  5.038935e+11
# I. Tiền và các khoản tương đương tiền   2.295451e+09  6.537815e+10
# 1. Tiền                                 1.064509e+08  6.537815e+10
# 2. Các khoản tương đương tiền           2.189000e+09  0.000000e+00
#
#                                                  CST           BSG  KLB  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.606217e+12  1.044683e+11  NaN
# I. Tiền và các khoản tương đương tiền   8.266465e+08  3.221881e+10  NaN
# 1. Tiền                                 8.266465e+08  2.218807e+09  NaN
# 2. Các khoản tương đương tiền           0.000000e+00  3.000000e+10  NaN
#
#                                                  KHB           BSL  VAB  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.127135e+09  1.999416e+11  NaN
# I. Tiền và các khoản tương đương tiền   1.566497e+08  7.782765e+10  NaN
# 1. Tiền                                 1.566497e+08  7.782765e+10  NaN
# 2. Các khoản tương đương tiền           0.000000e+00  0.000000e+00  NaN
#
#                                                  BSH           BLI  \
# ID
# TÀI SẢN                                          NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  2.811369e+11  2.103112e+12
# I. Tiền và các khoản tương đương tiền   1.941176e+11           NaN
# 1. Tiền                                 6.617641e+09           NaN
# 2. Các khoản tương đương tiền           1.875000e+11           NaN
#
#                                                  ATG           BSP  CSI  \
# ID
# TÀI SẢN                                          NaN           NaN  NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  3.442747e+10  1.674753e+11  NaN
# I. Tiền và các khoản tương đương tiền   1.039867e+09  7.668358e+10  NaN
# 1. Tiền                                 1.039867e+09  4.837192e+09  NaN
# 2. Các khoản tương đương tiền           0.000000e+00  7.184639e+10  NaN
#
#                                                  CLX  DSC           BSA
# ID
# TÀI SẢN                                          NaN  NaN           NaN
# A. Tài sản lưu động và đầu tư ngắn hạn  1.592267e+11  NaN  2.885795e+11
# I. Tiền và các khoản tương đương tiền   2.072991e+10  NaN  8.008503e+10
# 1. Tiền                                 2.072991e+10  NaN  2.085025e+09
# 2. Các khoản tương đương tiền           0.000000e+00  NaN  7.800000e+10

# %%
print(bs4.index)
# Out:
# Index(['TÀI SẢN', 'A. Tài sản lưu động và đầu tư ngắn hạn',
#        'I. Tiền và các khoản tương đương tiền', '1. Tiền',
#        '2. Các khoản tương đương tiền',
#        'II. Các khoản đầu tư tài chính ngắn hạn', '1. Chứng khoán kinh doanh',
#        '2. Dự phòng giảm giá chứng khoán kinh doanh',
#        '3. Đầu tư nắm giữ đến ngày đáo hạn',
#        'III. Các khoản phải thu ngắn hạn',
#        ...
#        'II. Nguồn kinh phí, quỹ khác', '1. Quỹ dự phòng trợ cấp mất việc làm',
#        '2. Quỹ khen thưởng phúc lợi',
#        '3. Quỹ khen thưởng phúc lợi đưa đi đầu tư',
#        '4. Quỹ quản lý của cấp trên', '5. Nguồn kinh phí sự nghiệp',
#        '- Nguồn kinh phí sự nghiệp năm trước',
#        '- Nguồn kinh phí sự nghiệp năm nay',
#        '6. Nguồn kinh phí đã hình thành TSCĐ', 'C. LỢI ÍCH CỔ ĐÔNG THIỂU SỐ'],
#       dtype='object', name='ID', length=364)

# %%
bs4.columns
# Out:
# Index(['AAA', 'AAM', 'AAT', 'ABS', 'ABT', 'ACB', 'ACC', 'ACL', 'ADG', 'ADS',
#        ...
#        'BSL', 'VAB', 'BSH', 'BLI', 'ATG', 'BSP', 'CSI', 'CLX', 'DSC', 'BSA'],
#       dtype='object', length=848)

# %% [markdown]
# # Balance sheet of a specific company (AAA)

# %%
bs_aaa = bs4['AAA'].dropna()
bs_aaa.reset_index()
# Out:
#                                                             ID           AAA
# 0                       A. Tài sản lưu động và đầu tư ngắn hạn  5.336716e+12
# 1                        I. Tiền và các khoản tương đương tiền  1.987171e+12
# 2                                                      1. Tiền  1.156983e+12
# 3                                2. Các khoản tương đương tiền  8.301873e+11
# 4                      II. Các khoản đầu tư tài chính ngắn hạn  4.361560e+11
# 5                                    1. Chứng khoán kinh doanh  0.000000e+00
# 6                  2. Dự phòng giảm giá chứng khoán kinh doanh  0.000000e+00
# 7                           3. Đầu tư nắm giữ đến ngày đáo hạn  4.361560e+11
# 8                             III. Các khoản phải thu ngắn hạn  1.810385e+12
# 9                          1. Phải thu ngắn hạn của khách hàng  1.147548e+12
# 10                                  2. Trả trước cho người bán  3.726508e+11
# 11                                 3. Phải thu nội bộ ngắn hạn  0.000000e+00
# 12                  4. Phải thu theo tiến độ hợp đồng xây dựng  0.000000e+00
# 13                             5. Phải thu về cho vay ngắn hạn  8.490640e+10
# 14                                   6. Phải thu ngắn hạn khác  2.161060e+11
# 15                       7. Dự phòng phải thu ngắn hạn khó đòi -1.082620e+10
# 16                                       IV. Tổng hàng tồn kho  9.655736e+11
# 17                                             1. Hàng tồn kho  9.655736e+11
# 18                           2. Dự phòng giảm giá hàng tồn kho  0.000000e+00
# 19                                    V. Tài sản ngắn hạn khác  1.374305e+11
# 20                               1. Chi phí trả trước ngắn hạn  2.556156e+10
# 21                      2. Thuế giá trị gia tăng được khấu trừ  1.118689e+11
# 22                      3. Thuế và các khoản phải thu Nhà nước  0.000000e+00
# 23               4. Giao dịch mua bán lại trái phiếu chính phủ  0.000000e+00
# 24                                    5. Tài sản ngắn hạn khác  0.000000e+00
# 25                        B. Tài sản cố định và đầu tư dài hạn  4.654916e+12
# 26                               I. Các khoản phải thu dài hạn  2.789664e+11
# 27                          1. Phải thu dài hạn của khách hàng  2.178288e+11
# 28                 2. Vốn kinh doanh tại các đơn vị trực thuộc  0.000000e+00
# 29                                  3. Phải thu dài hạn nội bộ  0.000000e+00
# 30                              4. Phải thu về cho vay dài hạn  4.469959e+10
# 31                                    5. Phải thu dài hạn khác  1.643805e+10
# 32                        6. Dự phòng phải thu dài hạn khó đòi  0.000000e+00
# 33                                         II. Tài sản cố định  2.100840e+12
# 34                                 1. Tài sản cố định hữu hình  2.022420e+12
# 35                     1. Tài sản cố định hữu hình- Nguyên giá  3.482795e+12
# 36         1. Tài sản cố định hữu hình- Giá trị hao mòn lũy kế -1.460375e+12
# 37                           2. Tài sản cố định thuê tài chính  0.000000e+00
# 38               2. Tài sản cố định thuê tài chính- Nguyên giá  0.000000e+00
# 39   2. Tài sản cố định thuê tài chính- Giá trị hao mòn lũy kế  0.000000e+00
# 40                                  3. Tài sản cố định vô hình  7.842010e+10
# 41                      3. Tài sản cố định vô hình- Nguyên giá  9.750045e+10
# 42          3. Tài sản cố định vô hình- Giá trị hao mòn lũy kế -1.908035e+10
# 43                                    III. Bất động sản đầu tư  5.263475e+11
# 44                        III. Bất động sản đầu tư- Nguyên giá  5.898417e+11
# 45            III. Bất động sản đầu tư- Giá trị hao mòn lũy kế -6.349424e+10
# 46                                 IV. Tài sản dở dang dài hạn  8.531764e+12
# 47             1. Chi phí sản xuất, kinh doanh dở dang dài hạn  0.000000e+00
# 48                          2. chi phí xây dựng cơ bản dở dang  8.531764e+12
# 49                       V. Các khoản đầu tư tài chính dài hạn  5.699093e+11
# 50                                   1. Đầu tư vào công ty con  0.000000e+00
# 51                  2. Đầu tư vào công ty liên kết, liên doanh  5.219143e+11
# 52                              3. Đầu tư khác vào công cụ vốn  1.799500e+10
# 53               4. Dự phòng giảm giá đầu tư tài chính dài hạn  0.000000e+00
# 54                          5. Đầu tư nắm giữ đến ngày đáo hạn  3.000000e+10
# 55                               VI. Tổng tài sản dài hạn khác  2.891263e+11
# 56                                1. Chi phí trả trước dài hạn  2.870143e+11
# 57                           2. Tài sản Thuế thu nhập hoãn lại  2.112010e+09
# 58                                     3. Tài sản dài hạn khác  0.000000e+00
# 59                                     VII. Lợi thế thương mại  3.655068e+10
# 60                                           TỔNG CỘNG TÀI SẢN  9.991632e+12
# 61                                              A. Nợ phải trả  4.533250e+12
# 62                                              I. Nợ ngắn hạn  3.260485e+12
# 63                        1. Vay và nợ thuê tài chính ngắn hạn  2.172873e+12
# 64                       2. Vay và nợ dài hạn đến hạn phải trả  0.000000e+00
# 65                              3. Phải trả người bán ngắn hạn  5.982543e+11
# 66                                 4. Người mua trả tiền trước  1.478126e+11
# 67                      5. Thuế và các khoản phải nộp nhà nước  3.547516e+10
# 68                                  6. Phải trả người lao động  4.436789e+10
# 69                                7. Chi phí phải trả ngắn hạn  2.153497e+10
# 70                                 8. Phải trả nội bộ ngắn hạn  0.000000e+00
# 71         9. Phải trả theo tiến độ kế hoạch hợp đồng xây dựng  0.000000e+00
# 72                       10. Doanh thu chưa thực hiện ngắn hạn  6.606598e+10
# 73                                  11. Phải trả ngắn hạn khác  1.668830e+11
# 74                              12. Dự phòng phải trả ngắn hạn  0.000000e+00
# 75                                13. Quỹ khen thưởng phúc lợi  7.217994e+09
# 76                                         14. Quỹ bình ổn giá  0.000000e+00
# 77              15. Giao dịch mua bán lại trái phiếu chính phủ  0.000000e+00
# 78                                              II. Nợ dài hạn  1.272765e+12
# 79                               1. Phải trả người bán dài hạn  8.468566e+08
# 80                                 2. Chi phí phải trả dài hạn  0.000000e+00
# 81                        3. Phải trả nội bộ về vốn kinh doanh  0.000000e+00
# 82                                  4. Phải trả nội bộ dài hạn  0.000000e+00
# 83                                    5. Phải trả dài hạn khác  6.476803e+09
# 84                         6. Vay và nợ thuê tài chính dài hạn  1.175998e+12
# 85                                    7. Trái phiếu chuyển đổi  0.000000e+00
# 86                          8. Thuế thu nhập hoãn lại phải trả  0.000000e+00
# 87                            9. Dự phòng trợ cấp mất việc làm  0.000000e+00
# 88                               10. Dự phòng phải trả dài hạn  0.000000e+00
# 89                        11. Doanh thu chưa thực hiện dài hạn  8.944352e+10
# 90                    12. Quỹ phát triển khoa học và công nghệ  0.000000e+00
# 91                                     B. Nguồn vốn chủ sở hữu  5.458382e+12
# 92                                           I. Vốn chủ sở hữu  5.458382e+12
# 93                                1. Vốn đầu tư của chủ sở hữu  3.264345e+12
# 94                                     2. Thặng dư vốn cổ phần  7.125911e+11
# 95                         3. Quyền chọn chuyển đổi trái phiếu  0.000000e+00
# 96                                  4. Vốn khác của chủ sở hữu  2.654493e+10
# 97                                             5. Cổ phiếu quỹ  0.000000e+00
# 98                          6. Chênh lệch đánh giá lại tài sản  0.000000e+00
# 99                               7. Chênh lệch tỷ giá hối đoái -9.061593e+09
# 100                                   8. Quỹ đầu tư phát triển  8.048162e+10
# 101                                  9. Quỹ dự phòng tài chính  0.000000e+00
# 102                          10. Quỹ khác thuộc vốn chủ sở hữu  1.317740e+10
# 103                      11. Lợi nhuận sau thuế chưa phân phối  7.238946e+11
# 104             - LNST chưa phân phối lũy kế đến cuối kỳ trước  4.393939e+11
# 105                               - LNST chưa phân phối kỳ này  2.845007e+11
# 106                       12. Nguồn vốn đầu tư xây dựng cơ bản  0.000000e+00
# 107                        13. Quỹ hỗ trợ sắp xếp doanh nghiệp  0.000000e+00
# 108                    14. Lợi ích của cổ đông không kiểm soát  6.464093e+11
# 109                             II. Nguồn kinh phí và quỹ khác  0.000000e+00
# 110                                         1. Nguồn kinh phí   0.000000e+00
# 111            2. Nguồn kinh phí đã hình thành tài sản cố định  0.000000e+00
# 112                       3. Quỹ dự phòng trợ cấp mất việc làm  0.000000e+00
# 113                                        TỔNG CỘNG NGUỒN VỐN  9.991632e+12
